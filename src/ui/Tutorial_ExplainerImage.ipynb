# %%
import pylab
# %load_ext autoreload
# %autoreload 2
# %pylab inline
import warnings; warnings.simplefilter('ignore') ; warnings.filterwarnings('ignore')
import logging, sys
logging.disable(sys.maxsize)

from Xlib import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %%
name_image().head()
# Out:
#                            name
# 0  ILSVRC2012_val_00000027.JPEG
# 1  ILSVRC2012_val_00000069.JPEG
# 2  ILSVRC2012_val_00000076.JPEG
# 3  ILSVRC2012_val_00000091.JPEG
# 4  ILSVRC2012_val_00000129.JPEG

# %%
fileImg = ImgFile("ILSVRC2012_val_00000069.JPEG")
fileImg2 = ImgFile(1,dataset="mnist")

# %% [markdown]
# Explainers for MNIST

# %%
fileImg2.play("Lime")

# %%
fileImg2.explainLocal(display=True) #here display is set to true
# Out:
# Elapsed time (s):  1.8804594000030193
# Time spent = 1880 ms

# %%
fileImg2.play("DeepExplainer")
# Out:
# Extracting C:\Users\ricky\AppData\Local\Temp\train-labels-idx1-ubyte.gz
# Extracting C:\Users\ricky\AppData\Local\Temp\t10k-labels-idx1-ubyte.gz

# %% [markdown]
# DeepExplainer has 6 attribution methods  and you have to specifiy it as first parameter.

# %%
fileImg2.explainLocal("saliency",display=True)
# Out:
# DeepExplain: running "saliency" explanation method (1)
# Model with multiple inputs:  False
# Done
# Time spent = 108445 ms

# %%
fileImg2.explainLocal("elrp")
# Out:
# DeepExplain: running "elrp" explanation method (4)
# Model with multiple inputs:  False
# Done

# %%
fileImg2.display("elrp")
# Out:
# Time spent = 109176 ms

# %% [markdown]
# Explainers for IMAGENET

# %%
fileImg.play("Lime")
# Out:
# 642 maraca 7.5107586e-05
# 698 pajama, pyjama, pj's, jammies 0.00012771407
# 866 toyshop 0.00021373665
# 616 knee pad 0.0041116886
# 871 tricycle, trike, velocipede 0.9933415

# %%
fileImg.explainLocal()
# Out:
# Elapsed time (s):  1440.2427254999993

# %%
fileImg.display("Lime")
# Out:
# Time spent = 1440243 ms

# %%
fileImg.play("DeepExplainer")

# %%
fileImg.explainLocal("saliency")
# Out:
# DeepExplain: running "saliency" explanation method (1)
# Model with multiple inputs:  False
# Done

# %%
fileImg.display("saliency")
# Out:
# Time spent = 98317 ms

# %%
fileImg.play("DeepExplainer")

# %%
fileImg.explainLocal("grad*input")
# Out:
# DeepExplain: running "grad*input" explanation method (2)
# Model with multiple inputs:  False
# Done

# %%
fileImg.display("grad*input")
# Out:
# Time spent = 101707 ms

# %%
fileImg.play("Saliency")

# %%
fileImg.explainLocal("Integrated Gradients")
# Out:
# Prediction class: 871

# %%
fileImg.display("Integrated Gradients")
# Out:
# Time spent = 370567 ms

# %%
fileImg.play("Saliency")

# %%
fileImg.explainLocal("Vanilla Gradient")
# Out:
# Prediction class: 871

# %%
fileImg.display("Vanilla Gradient")
# Out:
# Time spent = 16323 ms
